# %% [markdown]
# <a href="https://colab.research.google.com/github/borjinipun/mechanical_fitting_failure/blob/main/mechanical_fitting_failure_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from os.path import join
from google.colab import drive

ROOT = "/content/drive"
drive.mount(ROOT)
# Out:
# Mounted at /content/drive

# %%
PROJ = "MyDrive/Colab_Notebooks/mechanical_fitting_failure_data" # This is a custom path.
PROJECT_PATH = join(ROOT, PROJ)
FILENAME="mechanical_fitting_failures_2011_2018-03.csv"
PROJECT_PATH_FILE = join(PROJECT_PATH,FILENAME)

# %%
import numpy as np
import pandas as pd
mf_df=pd.read_csv(PROJECT_PATH_FILE)
# some changes

# %%
mf_df.head()
# Out:
#   DATAFILE_AS_OF  ... MFF_NUMBER_FROM_OPERATOR
# 0       4/3/2018  ...                 00028186
# 1       4/3/2018  ...                 00028008
# 2       4/3/2018  ...                 00027950
# 3       4/3/2018  ...                 00027949
# 4       4/3/2018  ...                 00027912
#
# [5 rows x 54 columns]

# %%
mf_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 85611 entries, 0 to 85610
# Data columns (total 54 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   DATAFILE_AS_OF                 85611 non-null  object
#  1   FORM_REV                       85611 non-null  object
#  2   OPERATOR_ID                    85611 non-null  int64
#  3   REPORT_YEAR                    85611 non-null  int64
#  4   REPORT_NUMBER                  85611 non-null  int64
#  5   SUPPLEMENTAL_NUMBER            85611 non-null  int64
#  6   REPORT_TYPE                    85611 non-null  object
#  7   REPORT_DATE                    85611 non-null  object
#  8   FILING_DATE                    85611 non-null  object
#  9   OPERATOR_NAME                  85611 non-null  object
#  10  HQ_ADDRESS_STREET              85611 non-null  object
#  11  HQ_ADDRESS_CITY                85611 non-null  object
# ...

# %%
mf_df.describe
# Out:
# <bound method NDFrame.describe of       DATAFILE_AS_OF  ... MFF_NUMBER_FROM_OPERATOR
# 0           4/3/2018  ...                 00028186
# 1           4/3/2018  ...                 00028008
# 2           4/3/2018  ...                 00027950
# 3           4/3/2018  ...                 00027949
# 4           4/3/2018  ...                 00027912
# ...              ...  ...                      ...
# 85606       4/3/2018  ...                      NaN
# 85607       4/3/2018  ...                      NaN
# 85608       4/3/2018  ...                      NaN
# 85609       4/3/2018  ...                      NaN
# 85610       4/3/2018  ...                      NaN
#
# [85611 rows x 54 columns]>

# %%
mf_df.isnull( ).sum( )
# Out:
# DATAFILE_AS_OF                       0
# FORM_REV                             0
# OPERATOR_ID                          0
# REPORT_YEAR                          0
# REPORT_NUMBER                        0
# SUPPLEMENTAL_NUMBER                  0
# REPORT_TYPE                          0
# REPORT_DATE                          0
# FILING_DATE                          0
# OPERATOR_NAME                        0
# HQ_ADDRESS_STREET                    0
# HQ_ADDRESS_CITY                      0
# HQ_ADDRESS_COUNTY                79345
# HQ_ADDRESS_STATE                     0
# HQ_ADDRESS_ZIP                       0
# FAILURE_STATE                        0
# FAILURE_DATE                         0
# MF_INVOLVED_TEXT                     0
# MF_INVOLVED_OTHER                71434
# MF_TYPE_TEXT                         0
# MF_TYPE_OTHER                    82557
# LEAK_LOCATION_A_TEXT                 9
# LEAK_LOCATION_B_TEXT                 0
# LEAK_LOCATION_C_TEXT                 0
# ...

# %%
mf_df.memory_usage( )
# Out:
# Index                               128
# DATAFILE_AS_OF                   684888
# FORM_REV                         684888
# OPERATOR_ID                      684888
# REPORT_YEAR                      684888
# REPORT_NUMBER                    684888
# SUPPLEMENTAL_NUMBER              684888
# REPORT_TYPE                      684888
# REPORT_DATE                      684888
# FILING_DATE                      684888
# OPERATOR_NAME                    684888
# HQ_ADDRESS_STREET                684888
# HQ_ADDRESS_CITY                  684888
# HQ_ADDRESS_COUNTY                684888
# HQ_ADDRESS_STATE                 684888
# HQ_ADDRESS_ZIP                   684888
# FAILURE_STATE                    684888
# FAILURE_DATE                     684888
# MF_INVOLVED_TEXT                 684888
# MF_INVOLVED_OTHER                684888
# MF_TYPE_TEXT                     684888
# MF_TYPE_OTHER                    684888
# LEAK_LOCATION_A_TEXT             684888
# ...

# %%
mf_df.shape
# Out:
# (85611, 54)
